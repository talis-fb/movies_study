# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("./bases/definitive_dataset.csv", low_memory=False)

# %%
df['genres'] = df['genres'].apply(json.loads)
df['production_companies'] = df['production_companies'].apply(json.loads)

# %%
df
# Out:
#       Unnamed: 0          id                           Title  Year  \
# 0              0  tt20114686                           Femme  2023
# 1              1  tt30467885         Goebbels and the Führer  2024
# 2              2  tt28223926                        Skincare  2024
# 3              3   tt6318608  Nightwatch: Demons Are Forever  2023
# 4              4   tt6432466                           Moxie  2021
# ...          ...         ...                             ...   ...
# 9657        9682   tt9887520                  Season of Love  2019
# 9658        9683   tt9894470                             VFW  2019
# 9659        9684   tt9896916              Pilgrim's Progress  2019
# 9660        9685   tt9900782                          Kaithi  2019
# 9661        9686   tt9914942          Life Without Sara Amat  2019
#
#        BoxOffice Production   budget  \
# 0       $187,053        NaN        0
# 1            NaN        NaN        0
# 2       $456,590        NaN        0
# 3            NaN        NaN  4300000
# 4            NaN        NaN        0
# ...          ...        ...      ...
# 9657         NaN        NaN        0
# 9658         NaN        NaN  1000000
# 9659  $1,294,596        NaN        0
# 9660         NaN        NaN        0
# 9661         NaN        NaN        0
#
#                                           genres original_language  \
# 0                     [Thriller, Romance, Drama]                en
# 1                    [History, Drama, Biography]                de
# 2     [Thriller, Horror, Comedy, Mystery, Drama]                en
# 3                    [Thriller, Horror, Mystery]                da
# 4                         [Comedy, Drama, Music]                en
# ...                                          ...               ...
# 9657                           [Romance, Comedy]                en
# 9658           [Action, Thriller, Horror, Crime]                en
# 9659              [Adventure, Family, Animation]                en
# 9660            [Action, Thriller, Drama, Crime]                ta
# 9661                            [Romance, Drama]                ca
#
#       popularity                               production_companies  revenue  \
# 0         2.8926                                      [Agile Films]        0
# 1         2.1574  [Zeitsprung Pictures, SWR, act headquarter media]   547033
# 2         5.4150  [Jalapeno Goat, Iervolino & Lady Bacardi Enter...   451381
# 3        33.0393                             [Nordisk Film Denmark]        0
# 4         3.1624                           [Paper Kite Productions]        0
# ...          ...                                                ...      ...
# 9657      0.6198                    [Tello Films, DASH Productions]        0
# 9658      1.1559  [Fangoria Films, Channel 83 Films, Good Wizard...    23101
# 9659      1.3392     [Cat In The Mill Studio, Herald Entertainment]        0
# 9660      1.6570    [Dream Warrior Pictures, Vivekandanda Pictures]        0
# 9661      0.8428                           [Massa d'Or Produccions]        0
#
#       runtime  Metacritic  imdb  rotten
# 0          99        69.0  73.0    93.0
# 1         123         NaN  67.0     NaN
# 2          96         NaN  57.0    69.0
# 3         117        50.0  58.0    69.0
# 4         111        54.0  67.0    70.0
# ...       ...         ...   ...     ...
# 9657      105         NaN  66.0     NaN
# 9658       92        72.0  61.0    85.0
# 9659      108         NaN  63.0    60.0
# 9660      147         NaN  84.0   100.0
# 9661       71         NaN  68.0     NaN
#
# [9662 rows x 16 columns]

# %%
df['Year'].value_counts()
# Out:
# Year
# 2024    1469
# 2023    1156
# 2022    1062
# 2021    1004
# 2019     996
# 2016     992
# 2015     991
# 2018     991
# 2017     989
# 2025       8
# 2020       2
# 2010       1
# 2014       1
# Name: count, dtype: int64
