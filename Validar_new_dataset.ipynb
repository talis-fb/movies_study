# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
raw_tmdb_df = pd.read_csv("./bases/tmdb.csv")

# %%
new_raw_tmdb_df = pd.read_csv("./bases/new/final_extracted_tmdb.csv")

# %%
def is_valid_json(s):
    try:
        json.loads(s)
        return True
    except (json.JSONDecodeError, TypeError):
        return False

raw_tmdb_df["is_valid_response"] = raw_tmdb_df["response"].apply(is_valid_json)
new_raw_tmdb_df["is_valid_response"] = new_raw_tmdb_df["response"].apply(is_valid_json)

# %%
raw_tmdb_df[~raw_tmdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, response, is_valid_response]
# Index: []

# %%
new_raw_tmdb_df[~new_raw_tmdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, response, is_valid_response]
# Index: []

# %%
new_raw_tmdb_df.shape
# Out:
# (6510, 4)

# %%
raw_tmdb_df.shape
# Out:
# (3950, 4)

# %%
old_raw_tmdb_df = raw_tmdb_df[~raw_tmdb_df['imdb_id'].isin(new_raw_tmdb_df['imdb_id'])]

# %%
old_raw_tmdb_df.shape
# Out:
# (3177, 4)

# %%
tmdb_df = pd.concat([old_raw_tmdb_df, new_raw_tmdb_df])

# %%
tmdb_df.shape == tmdb_df[tmdb_df["is_valid_response"] == True].shape
# Out:
# True

# %%
tmdb_df["value"] = tmdb_df.loc[:,"response"].apply(json.loads)

tmdb_df = tmdb_df.drop(["is_valid_response", "response"], axis=1)

norm_tmdb_df = pd.json_normalize(tmdb_df["value"])

# norm_tmdb_df["id"] = norm_tmdb_df["imdb_id"]

final_tmdb_df = pd.merge(tmdb_df, norm_tmdb_df, how="inner", on="imdb_id")

# %%
final_tmdb_df
# Out:
#          id_x     imdb_id                                              value  \
# 0      974576  tt20215234  {'adult': False, 'backdrop_path': '/1YMrOtrW7b...
# 1     1097549  tt30057084  {'adult': False, 'backdrop_path': '/hbFVmSYKvr...
# 2     1064213  tt28607951  {'adult': False, 'backdrop_path': '/87GU2ifjNY...
# 3      558449   tt9218128  {'adult': False, 'backdrop_path': '/euYIwmwkmz...
# 4     1082195  tt26625693  {'adult': False, 'backdrop_path': '/aMbKYfaexi...
# ...       ...         ...                                                ...
# 9682   998999  tt13260630  {'adult': False, 'backdrop_path': '/aKUuZDGejA...
# 9683   999142  tt33298252  {'adult': False, 'backdrop_path': '/tZ7ki6JMgE...
# 9684   999205   tt8889818  {'adult': False, 'backdrop_path': '/tviTAFuCFR...
# 9685   999278  tt15307448  {'adult': False, 'backdrop_path': '/sBk6nzxhtT...
# 9686   999812  tt16374130  {'adult': False, 'backdrop_path': '/iQCKhE4VBL...
#
#       adult                     backdrop_path  belongs_to_collection  \
# 0     False  /1YMrOtrW7b4pL2lfD8UciZPOJGs.jpg                    NaN
# 1     False  /hbFVmSYKvrqr9JuKVZ8l71kRQew.jpg                    NaN
# 2     False  /87GU2ifjNYtgYtcRH1NNH1P4ODo.jpg                    NaN
# 3     False  /euYIwmwkmz95mnXvufEmbL6ovhZ.jpg                    NaN
# 4     False  /aMbKYfaexixvsBZKc5whYO7yibR.jpg                    NaN
# ...     ...                               ...                    ...
# 9682  False  /aKUuZDGejALdxwLwDndwSyQQRIY.jpg                    NaN
# 9683  False  /tZ7ki6JMgEliY4u4XJmABZfAT2g.jpg                    NaN
# 9684  False  /tviTAFuCFRLElylvBAMPjdRnCDZ.jpg                    NaN
# 9685  False  /sBk6nzxhtTkrn9JZj32vaRki0QG.jpg                    NaN
# 9686  False  /iQCKhE4VBLplj62A41UFtgLZSIz.jpg                    NaN
#
#          budget                                             genres  \
# 0      20000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 1      20000000                      [{'id': 18, 'name': 'Drama'}]
# 2       6000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 3     310000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4      20000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# ...         ...                                                ...
# 9682          0                      [{'id': 18, 'name': 'Drama'}]
# 9683    2900000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 9684          0  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...
# 9685     250000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 9686          0  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
#
#                                                homepage     id_y  ...  \
# 0                https://www.focusfeatures.com/conclave   974576  ...
# 1                   https://a24films.com/films/babygirl  1097549  ...
# 2                                    https://anora.film  1064213  ...
# 3                           https://www.gladiator.movie   558449  ...
# 4                                http://theordermov.com  1082195  ...
# ...                                                 ...      ...  ...
# 9682                                                      998999  ...
# 9683                                                      999142  ...
# 9684                                                      999205  ...
# 9685             https://www.almostfamousproduction.it/   999278  ...
# 9686  https://watch.passionflix.com/watch/0d3da7c8-4...   999812  ...
#
#         status                                            tagline  \
# 0     Released  What happens behind these walls will change ev...
# 1     Released                         Get exactly what you want.
# 2     Released                                  Love is a hustle.
# 3     Released                         Prepare to be entertained.
# 4     Released                  Based on the chilling true story.
# ...        ...                                                ...
# 9682  Released      Miracles happen when you let go of the reins.
# 9683  Released
# 9684  Released
# 9685  Released
# 9686  Released
#
#                 title  video  vote_average vote_count  \
# 0            Conclave  False         7.211       2227
# 1            Babygirl  False         5.787        683
# 2               Anora  False         7.100       2103
# 3        Gladiator II  False         6.751       3275
# 4           The Order  False         6.573        587
# ...               ...    ...           ...        ...
# 9682          Adeline  False         6.800          8
# 9683            Rabia  False         6.471         17
# 9684         Stowaway  False         6.298         84
# 9685    The Goldsmith  False         5.966         87
# 9686  Resisting Roots  False         5.615         13
#
#      belongs_to_collection.id belongs_to_collection.name  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                   1069584.0       Gladiator Collection
# 4                         NaN                        NaN
# ...                       ...                        ...
# 9682                      NaN                        NaN
# 9683                      NaN                        NaN
# 9684                      NaN                        NaN
# 9685                      NaN                        NaN
# 9686                      NaN                        NaN
#
#      belongs_to_collection.poster_path  belongs_to_collection.backdrop_path
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
# 3     /bk6nx2rGNdlKtBsB9XcrclVKItv.jpg     /1VdLvSIeHuwqCT13H9EafxCacGB.jpg
# 4                                  NaN                                  NaN
# ...                                ...                                  ...
# 9682                               NaN                                  NaN
# 9683                               NaN                                  NaN
# 9684                               NaN                                  NaN
# 9685                               NaN                                  NaN
# 9686                               NaN                                  NaN
#
# [9687 rows x 32 columns]

# %% [markdown]
# # OMDB

# %%
new_raw_omdb_df = pd.read_csv("./bases/new/final_extracted_omdb.csv")

# %%
def is_valid_json(s):
    try:
        json.loads(s)
        return True
    except (json.JSONDecodeError, TypeError):
        return False

raw_omdb_df["is_valid_response"] = raw_omdb_df["response"].apply(is_valid_json)
new_raw_omdb_df["is_valid_response"] = new_raw_omdb_df["response"].apply(is_valid_json)

# %%
old_raw_omdb_df = raw_omdb_df[~raw_omdb_df['id'].isin(new_raw_omdb_df['id'])]

# %%
omdb_df = pd.concat([old_raw_omdb_df, new_raw_omdb_df])

omdb_df["value"] = omdb_df.loc[:,"response"].apply(json.loads)

# %%
omdb_df
# Out:
#               id                                           response  \
# 0     tt20114686  {"Title": "Femme", "Year": "2023", "Rated": "N...
# 1     tt30467885  {"Title": "Goebbels and the F\u00fchrer", "Yea...
# 2     tt28223926  {"Title": "Skincare", "Year": "2024", "Rated":...
# 3      tt6318608  {"Title": "Nightwatch: Demons Are Forever", "Y...
# 4      tt6432466  {"Title": "Moxie", "Year": "2021", "Rated": "P...
# ...          ...                                                ...
# 6589   tt9887520  {"Title": "Season of Love", "Year": "2019", "R...
# 6590   tt9894470  {"Title": "VFW", "Year": "2019", "Rated": "Not...
# 6591   tt9896916  {"Title": "Pilgrim's Progress", "Year": "2019"...
# 6592   tt9900782  {"Title": "Kaithi", "Year": "2019", "Rated": "...
# 6593   tt9914942  {"Title": "Life Without Sara Amat", "Year": "2...
#
#       is_valid_response                                              value
# 0                  True  {'Title': 'Femme', 'Year': '2023', 'Rated': 'N...
# 1                  True  {'Title': 'Goebbels and the Führer', 'Year': '...
# 2                  True  {'Title': 'Skincare', 'Year': '2024', 'Rated':...
# 3                  True  {'Title': 'Nightwatch: Demons Are Forever', 'Y...
# 4                  True  {'Title': 'Moxie', 'Year': '2021', 'Rated': 'P...
# ...                 ...                                                ...
# 6589               True  {'Title': 'Season of Love', 'Year': '2019', 'R...
# 6590               True  {'Title': 'VFW', 'Year': '2019', 'Rated': 'Not...
# 6591               True  {'Title': 'Pilgrim's Progress', 'Year': '2019'...
# 6592               True  {'Title': 'Kaithi', 'Year': '2019', 'Rated': '...
# 6593               True  {'Title': 'Life Without Sara Amat', 'Year': '2...
#
# [9797 rows x 4 columns]

# %%
norm_omdb_df = pd.json_normalize(omdb_df["value"])

norm_omdb_df["id"] = norm_omdb_df["imdbID"]

# %%
omdb_df = omdb_df.drop(["is_valid_response", "response"], axis=1)

# %%
final_omdb_df = pd.merge(omdb_df, norm_omdb_df, how="inner", on="id")

# %%
final_omdb_df
# Out:
#               id                                              value  \
# 0     tt20114686  {'Title': 'Femme', 'Year': '2023', 'Rated': 'N...
# 1     tt30467885  {'Title': 'Goebbels and the Führer', 'Year': '...
# 2     tt28223926  {'Title': 'Skincare', 'Year': '2024', 'Rated':...
# 3      tt6318608  {'Title': 'Nightwatch: Demons Are Forever', 'Y...
# 4      tt6432466  {'Title': 'Moxie', 'Year': '2021', 'Rated': 'P...
# ...          ...                                                ...
# 9791   tt9887520  {'Title': 'Season of Love', 'Year': '2019', 'R...
# 9792   tt9894470  {'Title': 'VFW', 'Year': '2019', 'Rated': 'Not...
# 9793   tt9896916  {'Title': 'Pilgrim's Progress', 'Year': '2019'...
# 9794   tt9900782  {'Title': 'Kaithi', 'Year': '2019', 'Rated': '...
# 9795   tt9914942  {'Title': 'Life Without Sara Amat', 'Year': '2...
#
#                                Title  Year      Rated     Released  Runtime  \
# 0                              Femme  2023        N/A  05 Apr 2024   99 min
# 1            Goebbels and the Führer  2024        N/A  12 Sep 2024  135 min
# 2                           Skincare  2024          R  16 Aug 2024   96 min
# 3     Nightwatch: Demons Are Forever  2023  Not Rated  17 May 2024  118 min
# 4                              Moxie  2021      PG-13  03 Mar 2021  111 min
# ...                              ...   ...        ...          ...      ...
# 9791                  Season of Love  2019        N/A  30 Nov 2019  105 min
# 9792                             VFW  2019  Not Rated  14 Feb 2020   92 min
# 9793              Pilgrim's Progress  2019         PG  18 Apr 2019  108 min
# 9794                          Kaithi  2019  Not Rated  24 Oct 2019  145 min
# 9795          Life Without Sara Amat  2019        N/A  05 Feb 2020   74 min
#
#                              Genre                       Director  \
# 0                  Drama, Thriller  Sam H. Freeman, Ng Choon Ping
# 1        Biography, Drama, History                   Joachim Lang
# 2          Comedy, Horror, Mystery                  Austin Peters
# 3        Horror, Mystery, Thriller                   Ole Bornedal
# 4                    Comedy, Drama                    Amy Poehler
# ...                            ...                            ...
# 9791               Comedy, Romance                 Christin Baker
# 9792         Action, Crime, Horror                      Joe Begos
# 9793  Animation, Adventure, Family               Robert Fernandez
# 9794          Action, Crime, Drama               Lokesh Kanagaraj
# 9795                         Drama                      Laura Jou
#
#                                                Writer  ...   Type  DVD  \
# 0                       Sam H. Freeman, Ng Choon Ping  ...  movie  N/A
# 1                                        Joachim Lang  ...  movie  N/A
# 2          Sam Freilich, Deering Regan, Austin Peters  ...  movie  N/A
# 3                                        Ole Bornedal  ...  movie  N/A
# 4       Jennifer Mathieu, Tamara Chestna, Dylan Meyer  ...  movie  N/A
# ...                                               ...  ...    ...  ...
# 9791                                 Kathryn Trammell  ...  movie  N/A
# 9792                    Max Brallier, Matthew McArdle  ...  movie  N/A
# 9793                    John Bunyan, Robert Fernandez  ...  movie  N/A
# 9794  Lokesh Kanagaraj, Pon Parthiban, Sanjeev Tiwari  ...  movie  N/A
# 9795                             Coral Cruz, Pep Puig  ...  movie  N/A
#
#        BoxOffice Production Website Response Error Season Episode seriesID
# 0       $187,053        N/A     N/A     True   NaN    NaN     NaN      NaN
# 1            N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# 2       $456,590        N/A     N/A     True   NaN    NaN     NaN      NaN
# 3            N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# 4            N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# ...          ...        ...     ...      ...   ...    ...     ...      ...
# 9791         N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# 9792         N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# 9793  $1,294,596        N/A     N/A     True   NaN    NaN     NaN      NaN
# 9794         N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
# 9795         N/A        N/A     N/A     True   NaN    NaN     NaN      NaN
#
# [9796 rows x 31 columns]

# %% [markdown]
# # SETUP COMPLETE

# %%
# df = pd.merge(final_omdb_df, final_tmdb_df, how="inner", on="id")
final_tmdb_df['id'] = final_tmdb_df['imdb_id']

# %%
final_omdb_df['id']
# Out:
# 0       tt20114686
# 1       tt30467885
# 2       tt28223926
# 3        tt6318608
# 4        tt6432466
#            ...
# 9791     tt9887520
# 9792     tt9894470
# 9793     tt9896916
# 9794     tt9900782
# 9795     tt9914942
# Name: id, Length: 9796, dtype: object

# %%
df = pd.merge(final_omdb_df, final_tmdb_df, how="inner", on="id")

# %%
# To fix how it store objects and lists
def is_complex(val):
    return isinstance(val, (list, dict))

def serialize_complex_columns(df):
    df_copy = df.copy()
    for col in df.columns:
        if df[col].apply(lambda x: is_complex(x)).any():
            df_copy[col] = df[col].apply(json.dumps)
    return df_copy

# Serialize and save
df_serialized = serialize_complex_columns(df)

# %%
#df_serialized.to_csv('./bases/new_complete/complete_raw.csv')
