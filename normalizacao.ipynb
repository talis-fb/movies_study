# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
raw_omdb_df = pd.read_csv("./bases/omdb.csv")

# %%
raw_tmdb_df = pd.read_csv("./bases/tmdb.csv")

# %%
def is_valid_json(s):
    try:
        json.loads(s)
        return True
    except (json.JSONDecodeError, TypeError):
        return False

raw_omdb_df["is_valid_response"] = raw_omdb_df["response"].apply(is_valid_json)
raw_tmdb_df["is_valid_response"] = raw_tmdb_df["response"].apply(is_valid_json)

# %%
raw_omdb_df[~raw_omdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, response, is_valid_response]
# Index: []

# %%
raw_tmdb_df[~raw_tmdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, response, is_valid_response]
# Index: []

# %% [markdown]
# # Omdb setup dataframe

# %%
omdb_df = raw_omdb_df[raw_omdb_df["is_valid_response"] == True]

omdb_df["value"] = omdb_df.loc[:,"response"].apply(json.loads)

# %%
omdb_df = omdb_df.drop(["is_valid_response", "response"], axis=1)

# %%
omdb_df
# Out:
#               id                                              value
# 0     tt20114686  {'Title': 'Femme', 'Year': '2023', 'Rated': 'N...
# 1     tt30467885  {'Title': 'Goebbels and the Führer', 'Year': '...
# 2     tt28223926  {'Title': 'Skincare', 'Year': '2024', 'Rated':...
# 3      tt6318608  {'Title': 'Nightwatch: Demons Are Forever', 'Y...
# 4      tt6432466  {'Title': 'Moxie', 'Year': '2021', 'Rated': 'P...
# ...          ...                                                ...
# 3995  tt32064571  {'Title': 'Nova & Alice', 'Year': '2024', 'Rat...
# 3996  tt15600222  {'Title': 'An Action Hero', 'Year': '2022', 'R...
# 3997   tt8290476  {'Title': 'Blank', 'Year': '2022', 'Rated': 'N...
# 3998  tt26731970  {'Title': 'All the Long Nights', 'Year': '2024...
# 3999  tt18950300  {'Title': 'Shoulder Dance', 'Year': '2023', 'R...
#
# [4000 rows x 2 columns]

# %%
norm_omdb_df = pd.json_normalize(omdb_df["value"])

norm_omdb_df["id"] = norm_omdb_df["imdbID"]

# %%
final_omdb_df = pd.merge(omdb_df, norm_omdb_df, how="inner", on="id")

# %% [markdown]
# # TMDB Setup Dataframe

# %%
tmdb_df = raw_tmdb_df[raw_tmdb_df["is_valid_response"] == True]

tmdb_df["value"] = tmdb_df.loc[:,"response"].apply(json.loads)

tmdb_df = tmdb_df.drop(["is_valid_response", "response"], axis=1)

norm_tmdb_df = pd.json_normalize(tmdb_df["value"])

# norm_tmdb_df["id"] = norm_tmdb_df["imdb_id"]

final_tmdb_df = pd.merge(tmdb_df, norm_tmdb_df, how="inner", on="imdb_id")

# %%
final_tmdb_df["id"] = final_tmdb_df["imdb_id"]

# %% [markdown]
# # Setup complete DF

# %%
df = pd.merge(final_omdb_df, final_tmdb_df, how="inner", on="id")

# %%
df.columns
# Out:
# Index(['id', 'value_x', 'Title', 'Year', 'Rated', 'Released', 'Runtime',
#        'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country',
#        'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes',
#        'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website',
#        'Response', 'Season', 'Episode', 'seriesID', 'Error', 'id_x', 'imdb_id',
#        'value_y', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id_y', 'origin_country', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'belongs_to_collection.id',
#        'belongs_to_collection.name', 'belongs_to_collection.poster_path',
#        'belongs_to_collection.backdrop_path'],
#       dtype='object')

# %%
# To fix how it store objects and lists
def is_complex(val):
    return isinstance(val, (list, dict))

def serialize_complex_columns(df):
    df_copy = df.copy()
    for col in df.columns:
        if df[col].apply(lambda x: is_complex(x)).any():
            df_copy[col] = df[col].apply(json.dumps)
    return df_copy

# Serialize and save
df_serialized = serialize_complex_columns(df)

# %%
#df_serialized.to_csv("./bases/complete_db.csv")

df_serialized
# Out:
#               id                                            value_x  \
# 0     tt20114686  {"Title": "Femme", "Year": "2023", "Rated": "N...
# 1     tt30467885  {"Title": "Goebbels and the F\u00fchrer", "Yea...
# 2     tt28223926  {"Title": "Skincare", "Year": "2024", "Rated":...
# 3      tt6318608  {"Title": "Nightwatch: Demons Are Forever", "Y...
# 4      tt6432466  {"Title": "Moxie", "Year": "2021", "Rated": "P...
# ...          ...                                                ...
# 3945  tt32064571  {"Title": "Nova & Alice", "Year": "2024", "Rat...
# 3946  tt15600222  {"Title": "An Action Hero", "Year": "2022", "R...
# 3947   tt8290476  {"Title": "Blank", "Year": "2022", "Rated": "N...
# 3948  tt26731970  {"Title": "All the Long Nights", "Year": "2024...
# 3949  tt18950300  {"Title": "Shoulder Dance", "Year": "2023", "R...
#
#                                Title  Year      Rated     Released  Runtime  \
# 0                              Femme  2023        N/A  05 Apr 2024   99 min
# 1            Goebbels and the Führer  2024        N/A  12 Sep 2024  135 min
# 2                           Skincare  2024          R  16 Aug 2024   96 min
# 3     Nightwatch: Demons Are Forever  2023  Not Rated  17 May 2024  118 min
# 4                              Moxie  2021      PG-13  03 Mar 2021  111 min
# ...                              ...   ...        ...          ...      ...
# 3945                    Nova & Alice  2024        N/A  13 Sep 2024  110 min
# 3946                  An Action Hero  2022        N/A  02 Dec 2022  130 min
# 3947                           Blank  2022        N/A  31 Jan 2023   94 min
# 3948             All the Long Nights  2024        N/A  09 Feb 2024  119 min
# 3949                  Shoulder Dance  2023        N/A  14 Nov 2023  103 min
#
#                           Genre                       Director  \
# 0               Drama, Thriller  Sam H. Freeman, Ng Choon Ping
# 1     Biography, Drama, History                   Joachim Lang
# 2       Comedy, Horror, Mystery                  Austin Peters
# 3     Horror, Mystery, Thriller                   Ole Bornedal
# 4                 Comedy, Drama                    Amy Poehler
# ...                         ...                            ...
# 3945               Drama, Music                     Emma Bucht
# 3946      Action, Comedy, Crime                   Anirudh Iyer
# 3947    Drama, Sci-Fi, Thriller                Natalie Kennedy
# 3948                      Drama                     Shô Miyake
# 3949     Comedy, Drama, Romance                     Jay Arnold
#
#                                              Writer  ...    status  \
# 0                     Sam H. Freeman, Ng Choon Ping  ...  Released
# 1                                      Joachim Lang  ...  Released
# 2        Sam Freilich, Deering Regan, Austin Peters  ...  Released
# 3                                      Ole Bornedal  ...  Released
# 4     Jennifer Mathieu, Tamara Chestna, Dylan Meyer  ...  Released
# ...                                             ...  ...       ...
# 3945          Jonna Bolin-Cullberg, Bengt Braskered  ...  Released
# 3946                     Anirudh Iyer, Neeraj Yadav  ...  Released
# 3947                                 Stephen Herman  ...  Released
# 3948           Shô Miyake, Maiko Seo, Kiyohito Wada  ...  Released
# 3949                                     Jay Arnold  ...  Released
#
#                                                 tagline  \
# 0                                 Seduction is revenge.
# 1
# 2                          It's just a little cover-up.
# 3
# 4                                      Find your voice.
# ...                                                 ...
# 3945                  One summer can change everything.
# 3946
# 3947           Watching. Helping. Guiding. Controlling.
# 3948
# 3949  Best friends, 24 years later. One unforgettabl...
#
#                                title  video vote_average vote_count  \
# 0                              Femme  False        6.700        100
# 1                 Führer and Seducer  False        6.700         53
# 2                           Skincare  False        5.939         74
# 3     Nightwatch: Demons Are Forever  False        6.056         62
# 4                              Moxie  False        7.300        807
# ...                              ...    ...          ...        ...
# 3945                    Nova & Alice  False        6.600          5
# 3946                  An Action Hero  False        6.500         61
# 3947                           Blank  False        4.300         25
# 3948             All the Long Nights  False        7.200         18
# 3949                  Shoulder Dance  False        1.500          2
#
#      belongs_to_collection.id belongs_to_collection.name  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                   1172371.0      Nightwatch Collection
# 4                         NaN                        NaN
# ...                       ...                        ...
# 3945                      NaN                        NaN
# 3946                      NaN                        NaN
# 3947                      NaN                        NaN
# 3948                      NaN                        NaN
# 3949                      NaN                        NaN
#
#      belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3     /uOXeb4vKZLTROhKAewzUrP3dfzh.jpg                                None
# 4                                  NaN                                 NaN
# ...                                ...                                 ...
# 3945                               NaN                                 NaN
# 3946                               NaN                                 NaN
# 3947                               NaN                                 NaN
# 3948                               NaN                                 NaN
# 3949                               NaN                                 NaN
#
# [3950 rows x 63 columns]
