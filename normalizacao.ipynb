# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
raw_omdb_df = pd.read_csv("./bases/omdb.csv")

# %%
raw_tmdb_df = pd.read_csv("./bases/tmdb.csv")

# %%
def is_valid_json(s):
    try:
        json.loads(s)
        return True
    except (json.JSONDecodeError, TypeError):
        return False

raw_omdb_df["is_valid_response"] = raw_omdb_df["response"].apply(is_valid_json)
raw_tmdb_df["is_valid_response"] = raw_tmdb_df["response"].apply(is_valid_json)

# %%
raw_omdb_df[~raw_omdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, response, is_valid_response]
# Index: []

# %%
raw_tmdb_df[~raw_tmdb_df["is_valid_response"]]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, response, is_valid_response]
# Index: []

# %% [markdown]
# # Omdb setup dataframe

# %%
omdb_df = raw_omdb_df[raw_omdb_df["is_valid_response"] == True]

omdb_df["value"] = omdb_df.loc[:,"response"].apply(json.loads)

# %%
omdb_df = omdb_df.drop(["is_valid_response", "response"], axis=1)

# %%
omdb_df
# Out:
#               id                                              value
# 0     tt20114686  {'Title': 'Femme', 'Year': '2023', 'Rated': 'N...
# 1     tt30467885  {'Title': 'Goebbels and the Führer', 'Year': '...
# 2     tt28223926  {'Title': 'Skincare', 'Year': '2024', 'Rated':...
# 3      tt6318608  {'Title': 'Nightwatch: Demons Are Forever', 'Y...
# 4      tt6432466  {'Title': 'Moxie', 'Year': '2021', 'Rated': 'P...
# ...          ...                                                ...
# 3995  tt32064571  {'Title': 'Nova & Alice', 'Year': '2024', 'Rat...
# 3996  tt15600222  {'Title': 'An Action Hero', 'Year': '2022', 'R...
# 3997   tt8290476  {'Title': 'Blank', 'Year': '2022', 'Rated': 'N...
# 3998  tt26731970  {'Title': 'All the Long Nights', 'Year': '2024...
# 3999  tt18950300  {'Title': 'Shoulder Dance', 'Year': '2023', 'R...
#
# [4000 rows x 2 columns]

# %%
norm_omdb_df = pd.json_normalize(omdb_df["value"])

norm_omdb_df["id"] = norm_omdb_df["imdbID"]

# %%
final_omdb_df = pd.merge(omdb_df, norm_omdb_df, how="inner", on="id")

# %% [markdown]
# # TMDB Setup Dataframe

# %%
norm_tmdb_df
# Out:
#       adult                     backdrop_path  belongs_to_collection  \
# 0     False  /1YMrOtrW7b4pL2lfD8UciZPOJGs.jpg                    NaN
# 1     False  /hbFVmSYKvrqr9JuKVZ8l71kRQew.jpg                    NaN
# 2     False  /87GU2ifjNYtgYtcRH1NNH1P4ODo.jpg                    NaN
# 3     False  /euYIwmwkmz95mnXvufEmbL6ovhZ.jpg                    NaN
# 4     False  /aMbKYfaexixvsBZKc5whYO7yibR.jpg                    NaN
# ...     ...                               ...                    ...
# 3945  False  /yUvVYkpOojoIEWn1HJlrU1nR5bU.jpg                    NaN
# 3946  False  /gmnX4h9BQrBZOVjzfr2c3eBRmx3.jpg                    NaN
# 3947  False  /y4IgPGAx5msaeeCXEtvfWdmmGxP.jpg                    NaN
# 3948  False  /9TZY0Jk2G2papFIWgQzY1QwZklo.jpg                    NaN
# 3949  False  /vUI8wrIXzvbLru1GvJD5op1yOaZ.jpg                    NaN
#
#          budget                                             genres  \
# 0      20000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 1      20000000                      [{'id': 18, 'name': 'Drama'}]
# 2       6000000  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 3     310000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4      20000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# ...         ...                                                ...
# 3945          0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 3946          0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 3947     275650  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 3948          0                      [{'id': 18, 'name': 'Drama'}]
# 3949          0                      [{'id': 18, 'name': 'Drama'}]
#
#                                     homepage       id     imdb_id  \
# 0     https://www.focusfeatures.com/conclave   974576  tt20215234
# 1        https://a24films.com/films/babygirl  1097549  tt30057084
# 2                         https://anora.film  1064213  tt28607951
# 3                https://www.gladiator.movie   558449   tt9218128
# 4                     http://theordermov.com  1082195  tt26625693
# ...                                      ...      ...         ...
# 3945                                          1278076  tt32064571
# 3946                                           882826  tt15600222
# 3947                                           871891   tt8290476
# 3948                                          1086011  tt26731970
# 3949                                          1095239  tt18950300
#
#      origin_country original_language  ...    status  \
# 0              [US]                en  ...  Released
# 1              [US]                en  ...  Released
# 2              [US]                en  ...  Released
# 3              [US]                en  ...  Released
# 4              [US]                en  ...  Released
# ...             ...               ...  ...       ...
# 3945           [SE]                sv  ...  Released
# 3946           [IN]                hi  ...  Released
# 3947           [GB]                en  ...  Released
# 3948           [JP]                ja  ...  Released
# 3949           [US]                en  ...  Released
#
#                                                 tagline                title  \
# 0     What happens behind these walls will change ev...             Conclave
# 1                            Get exactly what you want.             Babygirl
# 2                                     Love is a hustle.                Anora
# 3                            Prepare to be entertained.         Gladiator II
# 4                     Based on the chilling true story.            The Order
# ...                                                 ...                  ...
# 3945                  One summer can change everything.         Nova & Alice
# 3946                                                          An Action Hero
# 3947           Watching. Helping. Guiding. Controlling.                Blank
# 3948                                                     All the Long Nights
# 3949  Best friends, 24 years later. One unforgettabl...       Shoulder Dance
#
#       video vote_average vote_count belongs_to_collection.id  \
# 0     False        7.211       2227                      NaN
# 1     False        5.787        683                      NaN
# 2     False        7.100       2103                      NaN
# 3     False        6.751       3275                1069584.0
# 4     False        6.573        587                      NaN
# ...     ...          ...        ...                      ...
# 3945  False        6.600          5                      NaN
# 3946  False        6.500         61                      NaN
# 3947  False        4.300         25                      NaN
# 3948  False        7.200         18                      NaN
# 3949  False        1.500          2                      NaN
#
#       belongs_to_collection.name  belongs_to_collection.poster_path  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3           Gladiator Collection   /bk6nx2rGNdlKtBsB9XcrclVKItv.jpg
# 4                            NaN                                NaN
# ...                          ...                                ...
# 3945                         NaN                                NaN
# 3946                         NaN                                NaN
# 3947                         NaN                                NaN
# 3948                         NaN                                NaN
# 3949                         NaN                                NaN
#
#      belongs_to_collection.backdrop_path
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3       /1VdLvSIeHuwqCT13H9EafxCacGB.jpg
# 4                                    NaN
# ...                                  ...
# 3945                                 NaN
# 3946                                 NaN
# 3947                                 NaN
# 3948                                 NaN
# 3949                                 NaN
#
# [3950 rows x 30 columns]

# %%
tmdb_df = raw_tmdb_df[raw_tmdb_df["is_valid_response"] == True]

tmdb_df["value"] = tmdb_df.loc[:,"response"].apply(json.loads)

tmdb_df = tmdb_df.drop(["is_valid_response", "response"], axis=1)

norm_tmdb_df = pd.json_normalize(tmdb_df["value"])

# norm_tmdb_df["id"] = norm_tmdb_df["imdb_id"]

final_tmdb_df = pd.merge(tmdb_df, norm_tmdb_df, how="inner", on="imdb_id")

# %%
final_tmdb_df["id"] = final_tmdb_df["imdb_id"]

# %% [markdown]
# # Setup complete DF

# %%
df = pd.merge(final_omdb_df, final_tmdb_df, how="inner", on="id")

# %%
df.columns
# Out:
# Index(['id', 'value_x', 'Title', 'Year', 'Rated', 'Released', 'Runtime',
#        'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country',
#        'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes',
#        'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website',
#        'Response', 'Season', 'Episode', 'seriesID', 'Error', 'id_x', 'imdb_id',
#        'value_y', 'adult', 'backdrop_path', 'belongs_to_collection', 'budget',
#        'genres', 'homepage', 'id_y', 'origin_country', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'belongs_to_collection.id',
#        'belongs_to_collection.name', 'belongs_to_collection.poster_path',
#        'belongs_to_collection.backdrop_path'],
#       dtype='object')

# %%
# To fix how it store objects and lists
def is_complex(val):
    return isinstance(val, (list, dict))

def serialize_complex_columns(df):
    df_copy = df.copy()
    for col in df.columns:
        if df[col].apply(lambda x: is_complex(x)).any():
            df_copy[col] = df[col].apply(json.dumps)
    return df_copy

# Serialize and save
df_serialized = serialize_complex_columns(df)

# %%
df_serialized.to_csv("./bases/complete_db.csv")
